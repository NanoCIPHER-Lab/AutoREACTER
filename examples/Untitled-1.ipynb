# %%
try:
    import AutoREACTER as arx   
    print("AutoREACTER imported successfully.")
except ImportError:
    print("Failed to import AutoREACTER.")

# %%
print(arx.__version__)
arx.load("example_1_inputs_count_mode.json")
# Out:
# 0.2.2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 print(arx.__version__)
# ----> 2 arx.load("example_1_inputs_count_mode.json")
#
# File /mnt/c/Users/janit/Documents/GitHub/AutoREACTER/AutoREACTER/__init__.py:121, in load(input_file)
#     103 """
#     104 Create (or replace) the global ARX workflow session.
#     105
#    (...)    118     Sets the module-level ``_active_workflow`` as a side-effect.
#     119 """
#     120 global _active_workflow
# --> 121 _active_workflow = ARXCLI(input_file)
#
# File /mnt/c/Users/janit/Documents/GitHub/AutoREACTER/AutoREACTER/arx_cli.py:88, in ARXCLI.__init__(self, input)
#      85 self.error_handler = self.EH.waterfall_order()
#      87 self.input = input
# ---> 88 abs_path = self.input.resolve()
#      89 print(f"[OK] Read input from {abs_path}")
#      91 # Parse the input file and create the session
#
# AttributeError: 'str' object has no attribute 'resolve'
