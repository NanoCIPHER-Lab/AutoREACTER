# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Janitha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe

# %%
import reaction_lammps_mupt
print(reaction_lammps_mupt.__file__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import reaction_lammps_mupt
#       2 print(reaction_lammps_mupt.__file__)
#
# ModuleNotFoundError: No module named 'reaction_lammps_mupt'

# %%
from reaction_lammps_mupt.detectors.functional_groups_detector import functional_groups_detection
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from reaction_lammps_mupt.detectors.functional_groups_detector import functional_groups_detection
#
# ModuleNotFoundError: No module named 'reaction_lammps_mupt'

# %%
import sys
print(sys.executable)

from reaction_lammps_mupt.detectors.functional_groups_detector import functional_groups_detection
print("OK:", functional_groups_detection)
# Out:
# C:\Users\Janitha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       1 import sys
#       2 print(sys.executable)
# ----> 4 from reaction_lammps_mupt.detectors.functional_groups_detector import functional_groups_detection
#       5 print("OK:", functional_groups_detection)
#
# ModuleNotFoundError: No module named 'reaction_lammps_mupt'

# %%
from reaction_lammps_mupt.detectors.functional_groups_detector import functional_groups_detection
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from reaction_lammps_mupt.detectors.functional_groups_detector import functional_groups_detection
#
# ModuleNotFoundError: No module named 'reaction_lammps_mupt'
